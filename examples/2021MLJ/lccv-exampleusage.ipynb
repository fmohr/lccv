# %%
from lccv import lccv
from evalutils import *

# %%
openmlid = 41161
X, y = get_dataset(openmlid)

# %% [markdown]
# # Running without Timeout

# %%
# %%time
lccv(sklearn.linear_model.LogisticRegression(), X, y)
# Out:
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# CPU times: user 7min 49s, sys: 12.4 s, total: 8min 2s
# Wall time: 2min 18s
# /home/felix/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# (0.012999999999999989,
#  0.012999999999999989,
#  {64: {'n': 3,
#    'mean': 0.4622,
#    'std': 0.011332548992467089,
#    'conf': (0.44937624922940494, 0.47502375077059505)},
#   18000: {'n': 10,
#    'mean': 0.012999999999999989,
#    'std': 0.002073644135332758,
#    'conf': (0.011714765666153258, 0.01428523433384672)}},
#  <lccv.EmpiricalLearningModel at 0x7f4df351b7d0>)

# %% [markdown]
# # Running With Timeout

# %%
# %%time
lccv(sklearn.linear_model.LogisticRegression(), X, y, timeout=5)
# Out:
# CPU times: user 5.87 s, sys: 2.75 s, total: 8.62 s
# Wall time: 5.8 s
# /home/felix/devel/lccv/lccv/lccv.py:197: RuntimeWarning: invalid value encountered in sqrt
#   return -b/(2 * a) + np.sqrt(inner)
# (0.4562,
#  0.4562,
#  {64: {'n': 2,
#    'mean': 0.4562,
#    'std': 0.009200000000000041,
#    'conf': (0.4434496848159829, 0.4689503151840171)}},
#  <lccv.EmpiricalLearningModel at 0x7f4df351b710>)

# %% [markdown]
# # Running with Threshold

# %%
# %%time
lccv(sklearn.tree.DecisionTreeClassifier(), X, y, r = 1.0, enforce_all_anchor_evaluations=True, timeout=500, verbose=True)
# Out:
# All anchor evaluations enforced, setting r to 1.0
# True
# Running LCCV on (20000, 4296)-shaped data for learner DecisionTreeClassifier() with r = 1.0. Overview:
# 	min_exp: 6
# 	max_exp: 14.135709286104401
# Adding point at size 64
# std of [0.4857]: 0.0
# Adding point at size 64
# std of [0.4857 0.4098]: 0.037949999999999984
# Confidence bounds for performance interval at 64: (0.4036108425179703, 0.49188915748202977). Size: 0.08827831496405947
# Adding point at size 64
# std of [0.4857 0.4098 0.4102]: 0.03568569585826916
# Confidence bounds for performance interval at 64: (0.4013441737277038, 0.46912249293896285). Size: 0.06777831921125904
# Adding point at size 64
# std of [0.4857 0.4098 0.4102 0.4883]: 0.038511232127783165
# Confidence bounds for performance interval at 64: (0.4168273300781229, 0.4801726699218771). Size: 0.06334533984375423
# Adding point at size 64
# std of [0.4857 0.4098 0.4102 0.4883 0.3858]: 0.04260866578526014
# Confidence bounds for performance interval at 64: (0.4046170269054109, 0.4673029730945891). Size: 0.06268594618917822
# Adding point at size 64
# std of [0.4857 0.4098 0.4102 0.4883 0.3858 0.3875]: 0.04288447336222698
# Confidence bounds for performance interval at 64: (0.3990860371790679, 0.4566806294875989). Size: 0.057594592308531034
# Adding point at size 64
# std of [0.4857 0.4098 0.4102 0.4883 0.3858 0.3875 0.4438]: 0.04009206751404846
# Confidence bounds for performance interval at 64: (0.40523205545883756, 0.45508223025544825). Size: 0.04985017479661069
# Adding point at size 64
# std of [0.4857 0.4098 0.4102 0.4883 0.3858 0.3875 0.4438 0.4373]: 0.03757702090373849
# Confidence bounds for performance interval at 64: (0.40919732485671095, 0.452902675143289). Size: 0.04370535028657807
# Adding point at size 64
# std of [0.4857 0.4098 0.4102 0.4883 0.3858 0.3875 0.4438 0.4373 0.4154]: 0.035767721153900894
# Confidence bounds for performance interval at 64: (0.40970022248851684, 0.44892199973370533). Size: 0.039221777245188494
# Adding point at size 64
# std of [0.4857 0.4098 0.4102 0.4883 0.3858 0.3875 0.4438 0.4373 0.4154 0.3324]: 0.044683952376664254
# Confidence bounds for performance interval at 64: (0.3963777142073699, 0.4428622857926301). Size: 0.046484571585260204
# Adding point at size 128
# std of [0.4003]: 0.0
# Adding point at size 128
# std of [0.4003 0.3657]: 0.017299999999999982
# Confidence bounds for performance interval at 128: (0.36287859224139357, 0.40312140775860644). Size: 0.04024281551721287
# Adding point at size 128
# std of [0.4003 0.3657 0.3998]: 0.01619403182245442
# Confidence bounds for performance interval at 128: (0.3732212294340722, 0.4039787705659278). Size: 0.03075754113185558
# Adding point at size 128
# std of [0.4003 0.3657 0.3998 0.3978]: 0.014579266099498972
# Confidence bounds for performance interval at 128: (0.37890962063897426, 0.4028903793610258). Size: 0.02398075872205152
# Adding point at size 128
# std of [0.4003 0.3657 0.3998 0.3978 0.36  ]: 0.017967014220509774
# Confidence bounds for performance interval at 128: (0.37150344808678926, 0.39793655191321076). Size: 0.0264331038264215
# Adding point at size 128
# std of [0.4003 0.3657 0.3998 0.3978 0.36   0.3567]: 0.01944365792060058
# Confidence bounds for performance interval at 128: (0.36699341491074594, 0.39310658508925406). Size: 0.026113170178508116
# Adding point at size 128
# std of [0.4003 0.3657 0.3998 0.3978 0.36   0.3567 0.4365]: 0.02672534530427349
# Confidence bounds for performance interval at 128: (0.37149923917857164, 0.40472933224999985). Size: 0.03323009307142821
# Adding point at size 128
# std of [0.4003 0.3657 0.3998 0.3978 0.36   0.3567 0.4365 0.4331]: 0.029091362012631863
# Confidence bounds for performance interval at 128: (0.3768196052800752, 0.41065539471992485). Size: 0.03383578943984966
# Adding point at size 128
# std of [0.4003 0.3657 0.3998 0.3978 0.36   0.3567 0.4365 0.4331 0.41  ]: 0.027899705737640206
# Confidence bounds for performance interval at 128: (0.38024746705329904, 0.4108414218355899). Size: 0.030593954782290878
# Adding point at size 128
# std of [0.4003 0.3657 0.3998 0.3978 0.36   0.3567 0.4365 0.4331 0.41   0.3815]: 0.02680123877734013
# Confidence bounds for performance interval at 128: (0.3801993788568987, 0.4080806211431014). Size: 0.0278812422862027
# Adding point at size 256
# std of [0.3368]: 0.0
# Adding point at size 256
# std of [0.3368 0.3307]: 0.003049999999999997
# Confidence bounds for performance interval at 256: (0.3302025841812861, 0.33729741581871386). Size: 0.007094831637427745
# Adding point at size 256
# std of [0.3368 0.3307 0.3698]: 0.017175628728585822
# Confidence bounds for performance interval at 256: (0.32945571603754503, 0.3620776172957884). Size: 0.03262190125824338
# Adding point at size 256
# std of [0.3368 0.3307 0.3698 0.3324]: 0.015960948436731452
# Confidence bounds for performance interval at 256: (0.32929828803712846, 0.3555517119628716). Size: 0.026253423925743147
# Adding point at size 256
# std of [0.3368 0.3307 0.3698 0.3324 0.3251]: 0.015869039038328706
# Confidence bounds for performance interval at 256: (0.3272867205285883, 0.35063327947141176). Size: 0.023346558942823448
# Adding point at size 256
# std of [0.3368 0.3307 0.3698 0.3324 0.3251 0.3094]: 0.01819932843693843
# Confidence bounds for performance interval at 256: (0.32181232629471396, 0.34625434037195274). Size: 0.024442014077238783
# Adding point at size 256
# std of [0.3368 0.3307 0.3698 0.3324 0.3251 0.3094 0.3798]: 0.02324605737912281
# Confidence bounds for performance interval at 256: (0.32611944223678446, 0.3550234149060727). Size: 0.028903972669288236
# Adding point at size 256
# std of [0.3368 0.3307 0.3698 0.3324 0.3251 0.3094 0.3798 0.3578]: 0.022478809465805803
# Confidence bounds for performance interval at 256: (0.3296525927401878, 0.3557974072598122). Size: 0.02614481451962436
# Adding point at size 256
# std of [0.3368 0.3307 0.3698 0.3324 0.3251 0.3094 0.3798 0.3578 0.3787]: 0.02402030519640406
# Confidence bounds for performance interval at 256: (0.33355226018129336, 0.35989218426315106). Size: 0.026339924081857702
# Adding point at size 256
# std of [0.3368 0.3307 0.3698 0.3324 0.3251 0.3094 0.3798 0.3578 0.3787 0.3557]: 0.022946276386376956
# Confidence bounds for performance interval at 256: (0.335684531329879, 0.35955546867012095). Size: 0.023870937340241927
# Adding point at size 512
# std of [0.3092]: 0.0
# Adding point at size 512
# std of [0.3092 0.3093]: 4.999999999999449e-05
# Confidence bounds for performance interval at 512: (0.3091918456423162, 0.30930815435768383). Size: 0.0001163087153676079
# Switching to hold-out mode.
# Adding point at size 512
# std of [0.3092 0.3093 0.3588]: 0.023358129681595268
# Confidence bounds for performance interval at 512: (0.303584462681841, 0.3479488706514923). Size: 0.0443644079696513
# Adding point at size 512
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1307, in time
#     out = eval(code, glob, local_ns)
#   File "<timed eval>", line 1, in <module>
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 279, in lccv
#     elm.compute_and_add_sample(size, seed, (deadline - time.time()) * 1000 if deadline is not None else None)
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 83, in compute_and_add_sample
#     error_rate = evaluate(sklearn.base.clone(self.learner), self.X, self.y, size, seed, timeout / 1000 if timeout is not None else None)
#   File "/home/felix/devel/lccv/lccv/evalutils.py", line 48, in evaluate
#     X_test = X[mask_test][:10000]
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1307, in time
#     out = eval(code, glob, local_ns)
#   File "<timed eval>", line 1, in <module>
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 279, in lccv
#     elm.compute_and_add_sample(size, seed, (deadline - time.time()) * 1000 if deadline is not None else None)
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 83, in compute_and_add_sample
#     error_rate = evaluate(sklearn.base.clone(self.learner), self.X, self.y, size, seed, timeout / 1000 if timeout is not None else None)
#   File "/home/felix/devel/lccv/lccv/evalutils.py", line 48, in evaluate
#     X_test = X[mask_test][:10000]
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-e51ac56f89d9>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', 'lccv(sklearn.tree.DecisionTreeClassifier(), X, y, r = 1.0, enforce_all_anchor_evaluations=True, timeout=500, verbose=True)\n')
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2371, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-61>", line 2, in time
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1309, in time
#     self.shell.showtraceback()
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1307, in time
#     out = eval(code, glob, local_ns)
#   File "<timed eval>", line 1, in <module>
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 279, in lccv
#     elm.compute_and_add_sample(size, seed, (deadline - time.time()) * 1000 if deadline is not None else None)
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 83, in compute_and_add_sample
#     error_rate = evaluate(sklearn.base.clone(self.learner), self.X, self.y, size, seed, timeout / 1000 if timeout is not None else None)
#   File "/home/felix/devel/lccv/lccv/evalutils.py", line 48, in evaluate
#     X_test = X[mask_test][:10000]
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-e51ac56f89d9>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', 'lccv(sklearn.tree.DecisionTreeClassifier(), X, y, r = 1.0, enforce_all_anchor_evaluations=True, timeout=500, verbose=True)\n')
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2371, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-61>", line 2, in time
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1309, in time
#     self.shell.showtraceback()
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/felix/anaconda3/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1307, in time
#     out = eval(code, glob, local_ns)
#   File "<timed eval>", line 1, in <module>
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 279, in lccv
#     elm.compute_and_add_sample(size, seed, (deadline - time.time()) * 1000 if deadline is not None else None)
#   File "/home/felix/devel/lccv/lccv/lccv.py", line 83, in compute_and_add_sample
#     error_rate = evaluate(sklearn.base.clone(self.learner), self.X, self.y, size, seed, timeout / 1000 if timeout is not None else None)
#   File "/home/felix/devel/lccv/lccv/evalutils.py", line 48, in evaluate
#     X_test = X[mask_test][:10000]
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-e51ac56f89d9>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', 'lccv(sklearn.tree.DecisionTreeClassifier(), X, y, r = 1.0, enforce_all_anchor_evaluations=True, timeout=500, verbose=True)\n')
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2371, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-61>", line 2, in time
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1309, in time
#     self.shell.showtraceback()
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/felix/anaconda3/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt

# %% [markdown]
# # Making Recommendations on whether or not collect more data

# %%
from lccv import lccv
from evalutils import *

def check_possible_improvement(learner, X, y):
    n = X.shape[0]
    target = int(0.9 * n)
    half = int(target/2)
    print("Conducting validation on " + str(half) + "/" + str(target) + " instances.")
    validation_score, mean_estimates, estimates, elm = lccv(learner(), X, y, r = 1.0, enforce_all_anchor_evaluations=True, target = half, timeout=500, verbose=False)
    
    prediction_on_full = elm.get_ipl_estimate_at_target(target)
    expected_improvement = validation_score - prediction_on_full
    print("Score at half size (" + str(half) + "):", validation_score)
    print("Estimated score on full data (" + str(target) + " instances):", prediction_on_full)
    print("This would be an improvement of:", expected_improvement)
    recommendation = expected_improvement >= 0.01
    print("Recommending to double the number of instances:", recommendation)
    
    # now computing the true performance there
    print("Now computing the TRUE performance at the target.")
    for seed in range(10):
        elm.compute_and_add_sample(target, seed=seed)
    true_performance_at_target = np.mean(elm.get_values_at_anchor(target))
    true_improvement_at_target = validation_score - true_performance_at_target
    print("True performance at target:", true_performance_at_target)
    print("The true improvement is:", true_improvement_at_target)
    print("Recommendation was " + ("good" if (recommendation and true_improvement_at_target >= 0.01 or not recommendation and true_improvement_at_target < 0.01) else "bad"))

    
learner = sklearn.tree.DecisionTreeClassifier
print("Conducting recommendation analysis now only for " + learner.__name__)

print("\n----------------- 1 -----------------")
print("Doing this on higgs. Here we *will* recognize saturation and the recommendation for more data will be good.")
openmlid = 23512
X, y = get_dataset(openmlid)
check_possible_improvement(learner, X, y)

print("\n----------------- 2 -----------------")
print("Doing this on Madelon will be overly optimistic, but the recommendation for more data would still be correct.")
openmlid = 1485
X, y = get_dataset(openmlid)
check_possible_improvement(learner, X, y)

print("\n----------------- 3 -----------------")
print("We are also good in recognizing it on wine-quality-white!")
openmlid = 40498
X, y = get_dataset(openmlid)
check_possible_improvement(learner, X, y)

print("\n----------------- 4 -----------------")
print("On amazon, it works also well!")
openmlid = 1457
X, y = get_dataset(openmlid)
check_possible_improvement(learner, X, y)
# Out:
# Conducting recommendation analysis now only for DecisionTreeClassifier
#
# ----------------- 1 -----------------
# Doing this on higgs. Here we *will* recognize saturation and the recommendation for more data will be good.
# Conducting validation on 44122/88244 instances.
# Score at half size (44122): 0.37606000000000006
# Estimated score on full data (88244 instances): 0.36826329002668334
# This would be an improvement of: 0.007796709973316718
# Recommending to double the number of instances: False
# Now computing the TRUE performance at the target.
# True performance at target: 0.3715553289138195
# The true improvement is: 0.004504671086180578
# Recommendation was good
#
# ----------------- 2 -----------------
# Doing this on Madelon will be overly optimistic, but the recommendation for more data would still be correct.
# Conducting validation on 1170/2340 instances.
# Score at half size (1170): 0.3336363636363637
# Estimated score on full data (2340 instances): 0.2976369490387043
# This would be an improvement of: 0.035999414597659374
# Recommending to double the number of instances: True
# Now computing the TRUE performance at the target.
# True performance at target: 0.2353846153846154
# The true improvement is: 0.09825174825174829
# Recommendation was good
#
# ----------------- 3 -----------------
# We are also good in recognizing it on wine-quality-white!
# Conducting validation on 2204/4408 instances.
# Score at half size (2204): 0.46726057906458796
# Estimated score on full data (4408 instances): 0.4512591758076496
# This would be an improvement of: 0.01600140325693833
# Recommending to double the number of instances: True
# Now computing the TRUE performance at the target.
# True performance at target: 0.3714285714285714
# The true improvement is: 0.09583200763601657
# Recommendation was good
#
# ----------------- 4 -----------------
# On amazon, it works also well!
# Conducting validation on 675/1350 instances.
# Score at half size (675): 0.6408484848484849
# Estimated score on full data (1350 instances): 0.5582903918255298
# This would be an improvement of: 0.08255809302295514
# Recommending to double the number of instances: True
# Now computing the TRUE performance at the target.
# True performance at target: 0.5706666666666667
# The true improvement is: 0.07018181818181823
# Recommendation was good
